# %% [markdown]
# #Directory, Libraries and data

# %%
# %cd /content/drive/MyDrive/Business Analyst course/Predictive Analytics/Prophet
# Out:
# /content/drive/MyDrive/Business Analyst course/Predictive Analytics/Prophet

# %%
#import libraries
import numpy as np
import pandas as pd
from prophet import Prophet
from prophet.diagnostics import cross_validation
from prophet.utilities import regressor_coefficients
from sklearn.metrics import mean_squared_error
from prophet.plot import plot_cross_validation_metric
from sklearn.model_selection import ParameterGrid

# %%
#data
df = pd.read_csv("DHS_weekly.csv")
df.head()
# Out:
#         Date  Total Individuals in Shelter  Easter  Thanksgiving  Christmas  \
# 0   1/5/2014                        354354       0             0          0
# 1  1/12/2014                        358103       0             0          0
# 2  1/19/2014                        359491       0             0          0
# 3  1/26/2014                        362880       0             0          0
# 4   2/2/2014                        364125       0             0          0
#
#    Temperature
# 0     0.848000
# 1     3.257143
# 2     5.632857
# 3    -1.850000
# 4     1.177143

# %%
#date vairable and renamee date and Y
df.Date = pd.to_datetime(df.Date,
                         format = "%m/%d/%Y")
df = df.rename(columns = {'Date': 'ds',
                          'Total Individuals in Shelter': 'y'})
df.head(1)
# Out:
#           ds       y  Easter  Thanksgiving  Christmas  Temperature
# 0 2014-01-05  354354       0             0          0        0.848

# %% [markdown]
# #Holidays

# %%
#Easter
easter_dates = df[df.Easter == 1].ds
easter = pd.DataFrame({'holiday': 'easter',
                      'ds': easter_dates,
                      'lower_window': -7,
                      'upper_window': 7})

# %%
#Thanksgiving
thanksgiving_dates = df[df.Thanksgiving == 1].ds
thanksgiving = pd.DataFrame({'holiday': 'thanksgiving',
                            'ds': thanksgiving_dates,
                            'lower_window': -7,
                            'upper_window': 7})

# %%
#combine events
holidays = pd.concat([easter, thanksgiving])
holidays
# Out:
#           holiday         ds  lower_window  upper_window
# 15         easter 2014-04-20            -7             7
# 65         easter 2015-04-05            -7             7
# 116        easter 2016-03-27            -7             7
# 171        easter 2017-04-16            -7             7
# 221        easter 2018-04-01            -7             7
# 276        easter 2019-04-21            -7             7
# 327        easter 2020-04-12            -7             7
# 47   thanksgiving 2014-11-30            -7             7
# 99   thanksgiving 2015-11-29            -7             7
# 151  thanksgiving 2016-11-27            -7             7
# 203  thanksgiving 2017-11-26            -7             7
# 255  thanksgiving 2018-11-25            -7             7
# 308  thanksgiving 2019-12-01            -7             7
# 360  thanksgiving 2020-11-29            -7             7

# %%
#finish df -> remove duplicated holidays
df = df.drop(columns = ["Easter", "Thanksgiving"])
df.head(0)
# Out:
# Empty DataFrame
# Columns: [ds, y, Christmas, Temperature]
# Index: []

# %% [markdown]
# #Prophet model

# %%
#Training and test split
test_weeks = 4
training = df.iloc[:-4,:]
test = df.iloc[-4:, :]
test
# Out:
#             ds       y  Christmas  Temperature
# 362 2020-12-13  375820          0     8.208571
# 363 2020-12-20  375615          0     3.535714
# 364 2020-12-27  374203          1     7.510000
# 365 2021-01-03  212514          0     6.625000

# %%
#Prophet model
m = Prophet(growth = 'linear',
            yearly_seasonality = True,
            weekly_seasonality = False,
            holidays = holidays,
            seasonality_mode = "multiplicative",
            seasonality_prior_scale = 10,
            holidays_prior_scale = 10,
            changepoint_prior_scale= 0.05)
m.add_regressor('Christmas')
m.add_regressor('Temperature')
m.fit(training)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/wyl9_yk_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/cp_b_lwj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24842', 'data', 'file=/tmp/tmpfeqaz1u8/wyl9_yk_.json', 'init=/tmp/tmpfeqaz1u8/cp_b_lwj.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_model95a135l6/prophet_model-20221128092719.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:27:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:27:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
#Coefficients
regressor_coefficients(m)
# Out:
#      regressor  regressor_mode     center  coef_lower      coef  coef_upper
# 0    Christmas  multiplicative   0.000000   -0.000182 -0.000182   -0.000182
# 1  Temperature  multiplicative  14.934939   -0.000221 -0.000221   -0.000221

# %% [markdown]
# #Forecasting

# %%
#future dataframe
future = m.make_future_dataframe(periods = test_weeks,
                                 freq = "W")
future = pd.concat([future, df.iloc[:,2:]], axis = 1)
future.tail()
# Out:
#             ds  Christmas  Temperature
# 361 2020-12-06          0    10.072857
# 362 2020-12-13          0     8.208571
# 363 2020-12-20          0     3.535714
# 364 2020-12-27          1     7.510000
# 365 2021-01-03          0     6.625000

# %%
#forecasting
forecast = m.predict(future)

# %%
#holidays
holiday = 'thanksgiving'
forecast[(forecast[holiday].abs() > 0) & (forecast['ds'] > '2020-01-01')][
    ['ds', holiday]]
# Out:
#             ds  thanksgiving
# 359 2020-11-22      0.002182
# 360 2020-11-29     -0.000994
# 361 2020-12-06     -0.003979

# %%
#retrieve the predictions
predictions = forecast.yhat[-test_weeks:]
predictions
# Out:
# 362    385741.922878
# 363    384829.381717
# 364    382621.308763
# 365    381544.749404
# Name: yhat, dtype: float64

# %%
#accuracy assessment
np.sqrt(mean_squared_error(test['y'], predictions))
# Out:
# 84890.53473499791

# %% [markdown]
# #Visualization

# %%
#Plot forecast
m.plot(forecast);

# %%
#model components
m.plot_components(forecast);

# %% [markdown]
# #Cross-Validation

# %%
#How many weeks of data we have
df.shape
# Out:
# (366, 4)

# %%
#CV
df_cv = cross_validation(m,
                         horizon = "4 W", # 28 days also possible
                         initial = "300 W", # 1500 days
                         parallel = 'processes')
# Out:
# INFO:prophet:Making 29 forecasts with cutoffs between 2019-10-13 00:00:00 and 2020-11-08 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f3deed2bf50>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/x0u_001m.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/mp0kzrtd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/oziw2ace.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75443', 'data', 'file=/tmp/tmpfeqaz1u8/mp0kzrtd.json', 'init=/tmp/tmpfeqaz1u8/oziw2ace.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_modelvp_puhk_/prophet_model-20221128092726.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:27:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/etzlq3md.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=15840', 'data', 'file=/tmp/tmpfeqaz1u8/x0u_001m.json', 'init=/tmp/tmpfeqaz1u8/etzlq3md.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_modelazyv6uy2/prophet_model-20221128092726.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:27:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:27:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 09:27:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/m87_zuzd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/3iayzkud.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/qq0ngng7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48469', 'data', 'file=/tmp/tmpfeqaz1u8/m87_zuzd.json', 'init=/tmp/tmpfeqaz1u8/3iayzkud.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_modelyat8q1mk/prophet_model-20221128092728.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:27:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/qfh4afbj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33133', 'data', 'file=/tmp/tmpfeqaz1u8/qq0ngng7.json', 'init=/tmp/tmpfeqaz1u8/qfh4afbj.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_modelcuxaj8_0/prophet_model-20221128092728.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:27:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:27:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 09:27:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/7xiuzyd3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/wa3bi2e0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/mneu2sfi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/5__2vkzr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=13167', 'data', 'file=/tmp/tmpfeqaz1u8/wa3bi2e0.json', 'init=/tmp/tmpfeqaz1u8/mneu2sfi.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_modelfy_tmtat/prophet_model-20221128092730.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:27:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25473', 'data', 'file=/tmp/tmpfeqaz1u8/7xiuzyd3.json', 'init=/tmp/tmpfeqaz1u8/5__2vkzr.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_modelp06t3rsc/prophet_model-20221128092730.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:27:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:27:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 09:27:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/hs16722c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/0o2o6fdx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/kd_pfk04.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/d3jwgni_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=15692', 'data', 'file=/tmp/tmpfeqaz1u8/0o2o6fdx.json', 'init=/tmp/tmpfeqaz1u8/d3jwgni_.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_modelcxgpcxx1/prophet_model-20221128092731.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:27:31 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88816', 'data', 'file=/tmp/tmpfeqaz1u8/hs16722c.json', 'init=/tmp/tmpfeqaz1u8/kd_pfk04.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_modell3ofxmci/prophet_model-20221128092731.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# INFO:cmdstanpy:Chain [1] start processing
# 09:27:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:27:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 09:27:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/om8egxdp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/03llxl6x.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/v3zvld2l.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/3ocrpj_w.json
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=67711', 'data', 'file=/tmp/tmpfeqaz1u8/om8egxdp.json', 'init=/tmp/tmpfeqaz1u8/v3zvld2l.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_model3_bra08g/prophet_model-20221128092733.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:idx 0
# 09:27:33 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60291', 'data', 'file=/tmp/tmpfeqaz1u8/03llxl6x.json', 'init=/tmp/tmpfeqaz1u8/3ocrpj_w.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_modelmhpwibta/prophet_model-20221128092733.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# INFO:cmdstanpy:Chain [1] start processing
# 09:27:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:27:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 09:27:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/xjy00mp1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/2b4gfdmm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/in2ix9ap.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=15803', 'data', 'file=/tmp/tmpfeqaz1u8/xjy00mp1.json', 'init=/tmp/tmpfeqaz1u8/in2ix9ap.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_modelvgca8wpe/prophet_model-20221128092735.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:27:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/1bfwk43b.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=7667', 'data', 'file=/tmp/tmpfeqaz1u8/2b4gfdmm.json', 'init=/tmp/tmpfeqaz1u8/1bfwk43b.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_modelq80j4re8/prophet_model-20221128092735.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:27:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:27:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 09:27:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/cte064sc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/vjamjrpf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/_oi3oulv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/c34b5vf5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=16614', 'data', 'file=/tmp/tmpfeqaz1u8/cte064sc.json', 'init=/tmp/tmpfeqaz1u8/c34b5vf5.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_model9a5izomb/prophet_model-20221128092737.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:27:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64857', 'data', 'file=/tmp/tmpfeqaz1u8/vjamjrpf.json', 'init=/tmp/tmpfeqaz1u8/_oi3oulv.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_modelq4fbjevf/prophet_model-20221128092737.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:27:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:27:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 09:27:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/hcnb8qjv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/7sazp7cf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=32536', 'data', 'file=/tmp/tmpfeqaz1u8/hcnb8qjv.json', 'init=/tmp/tmpfeqaz1u8/7sazp7cf.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_modelixz9y03g/prophet_model-20221128092738.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:27:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/2djdocb7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/2m1nywqi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=32999', 'data', 'file=/tmp/tmpfeqaz1u8/2djdocb7.json', 'init=/tmp/tmpfeqaz1u8/2m1nywqi.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_model3emdgxk1/prophet_model-20221128092738.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:27:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:27:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 09:27:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/8om_50ap.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/331w5hu0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84772', 'data', 'file=/tmp/tmpfeqaz1u8/8om_50ap.json', 'init=/tmp/tmpfeqaz1u8/331w5hu0.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_modellny7lcu0/prophet_model-20221128092740.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:27:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/rmwn1d20.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/dxt0ouw5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68434', 'data', 'file=/tmp/tmpfeqaz1u8/rmwn1d20.json', 'init=/tmp/tmpfeqaz1u8/dxt0ouw5.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_modelifjrd2iw/prophet_model-20221128092740.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:27:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:27:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 09:27:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/c0376_ou.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/jcig39_w.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3823', 'data', 'file=/tmp/tmpfeqaz1u8/c0376_ou.json', 'init=/tmp/tmpfeqaz1u8/jcig39_w.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_modeli12cuyed/prophet_model-20221128092742.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:27:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/f1l1zn0g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/5bzrzl9i.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24117', 'data', 'file=/tmp/tmpfeqaz1u8/f1l1zn0g.json', 'init=/tmp/tmpfeqaz1u8/5bzrzl9i.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_modelt94yv5_7/prophet_model-20221128092742.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:27:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:27:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 09:27:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/zf_ompyx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/lsv4ztu1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83012', 'data', 'file=/tmp/tmpfeqaz1u8/zf_ompyx.json', 'init=/tmp/tmpfeqaz1u8/lsv4ztu1.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_modelmvvbnf30/prophet_model-20221128092744.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:27:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/42995fa0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/a1u6_oqb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96478', 'data', 'file=/tmp/tmpfeqaz1u8/42995fa0.json', 'init=/tmp/tmpfeqaz1u8/a1u6_oqb.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_modelhyame3r8/prophet_model-20221128092744.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:27:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:27:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 09:27:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/jhu8u9j6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/zrwxtm5r.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96975', 'data', 'file=/tmp/tmpfeqaz1u8/jhu8u9j6.json', 'init=/tmp/tmpfeqaz1u8/zrwxtm5r.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_modelrublgt0s/prophet_model-20221128092746.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:27:46 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/q1vbcs1q.json
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/vasnjfo5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42744', 'data', 'file=/tmp/tmpfeqaz1u8/q1vbcs1q.json', 'init=/tmp/tmpfeqaz1u8/vasnjfo5.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_model89h60xkp/prophet_model-20221128092746.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:27:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:27:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 09:27:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/hjvmqvfr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/pp9q793g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/rms5c6ph.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/j7ala1hr.json
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12828', 'data', 'file=/tmp/tmpfeqaz1u8/hjvmqvfr.json', 'init=/tmp/tmpfeqaz1u8/rms5c6ph.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_model5knoxa1u/prophet_model-20221128092748.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:27:48 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:idx 0
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92179', 'data', 'file=/tmp/tmpfeqaz1u8/pp9q793g.json', 'init=/tmp/tmpfeqaz1u8/j7ala1hr.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_modelqof7j0f5/prophet_model-20221128092748.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:27:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:27:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 09:27:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/xw_atbmd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/ntpv30mc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/05jgnthl.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27000', 'data', 'file=/tmp/tmpfeqaz1u8/xw_atbmd.json', 'init=/tmp/tmpfeqaz1u8/05jgnthl.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_model3v30ndc7/prophet_model-20221128092749.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:27:49 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/4mh3kloy.json
# DEBUG:cmdstanpy:idx 0
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# 09:27:49 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30245', 'data', 'file=/tmp/tmpfeqaz1u8/ntpv30mc.json', 'init=/tmp/tmpfeqaz1u8/4mh3kloy.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_modelxme07wo6/prophet_model-20221128092749.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# INFO:cmdstanpy:Chain [1] start processing
# 09:27:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 09:27:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/2re7dvxk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfeqaz1u8/hztdmng9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33864', 'data', 'file=/tmp/tmpfeqaz1u8/2re7dvxk.json', 'init=/tmp/tmpfeqaz1u8/hztdmng9.json', 'output', 'file=/tmp/tmpfeqaz1u8/prophet_model8q4bjgqq/prophet_model-20221128092751.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:27:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:27:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
#CV output
df_cv
# Out:
#             ds           yhat     yhat_lower     yhat_upper       y     cutoff
# 0   2019-10-20  419425.485291  418044.674420  420744.982031  420265 2019-10-13
# 1   2019-10-27  420148.451164  418857.493190  421367.859580  420670 2019-10-13
# 2   2019-11-03  420722.193620  419313.111601  422125.520911  419924 2019-10-13
# 3   2019-11-10  420917.494377  419566.919646  422402.855064  420624 2019-10-13
# 4   2019-11-03  420784.361854  419383.724031  422122.105040  419924 2019-10-27
# ..         ...            ...            ...            ...     ...        ...
# 111 2020-11-22  392561.232100  389222.060168  395685.085325  377413 2020-10-25
# 112 2020-11-15  389120.320544  385580.305544  392806.927140  377700 2020-11-08
# 113 2020-11-22  390600.316912  387338.455257  394108.157348  377413 2020-11-08
# 114 2020-11-29  389649.006581  386251.339065  392990.597499  376769 2020-11-08
# 115 2020-12-06  389057.900204  385290.158974  392528.960234  375444 2020-11-08
#
# [116 rows x 6 columns]

# %%
#CV visualization
plot_cross_validation_metric(df_cv, metric = "mape");
# Out:
# /usr/local/lib/python3.7/dist-packages/prophet/plot.py:544: FutureWarning: casting timedelta64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.
#   x_plt = df_none['horizon'].astype('timedelta64[ns]').astype(np.int64) / float(dt_conversions[i])
# /usr/local/lib/python3.7/dist-packages/prophet/plot.py:545: FutureWarning: casting timedelta64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.
#   x_plt_h = df_h['horizon'].astype('timedelta64[ns]').astype(np.int64) / float(dt_conversions[i])

# %% [markdown]
# #Parameter Tuning

# %%
#Parameter Grid
param_grid = {'seasonality_mode': ['additive', 'multiplicative'],
              'seasonality_prior_scale': [5, 10, 20],
              'holidays_prior_scale': [5, 10, 20],
              'changepoint_prior_scale': [0.01, 0.05, 0.1]}
grid = ParameterGrid(param_grid)
len(list(grid))
# Out:
# 54

# %%
#Parameter list
rmse = []

#Loop
for params in grid:
  #build the model
  m = Prophet(growth = 'linear',
              yearly_seasonality = True,
              weekly_seasonality = False,
              holidays = holidays,
              seasonality_mode = params['seasonality_mode'],
              seasonality_prior_scale = params['seasonality_prior_scale'],
              holidays_prior_scale = params['holidays_prior_scale'],
              changepoint_prior_scale= params['changepoint_prior_scale'])
  m.add_regressor('Christmas')
  m.add_regressor('Temperature')
  m.fit(training)

  #CV
  df_cv = cross_validation(m,
                          horizon = "4 W", # 28 days also possible
                          initial = "300 W", # 1500 days
                          parallel = 'processes') 
  
  #Measure and store the error
  error = np.sqrt(mean_squared_error(df_cv['y'], df_cv['yhat']))
  rmse.append(error)

# %%
#get the best parameters
tuning_results = pd.DataFrame(grid)
tuning_results['rmse'] = rmse
tuning_results
# Out:
#     changepoint_prior_scale  holidays_prior_scale seasonality_mode  \
# 0                      0.01                     5         additive
# 1                      0.01                     5         additive
# 2                      0.01                     5         additive
# 3                      0.01                     5   multiplicative
# 4                      0.01                     5   multiplicative
# 5                      0.01                     5   multiplicative
# 6                      0.01                    10         additive
# 7                      0.01                    10         additive
# 8                      0.01                    10         additive
# 9                      0.01                    10   multiplicative
# 10                     0.01                    10   multiplicative
# 11                     0.01                    10   multiplicative
# 12                     0.01                    20         additive
# 13                     0.01                    20         additive
# 14                     0.01                    20         additive
# 15                     0.01                    20   multiplicative
# 16                     0.01                    20   multiplicative
# 17                     0.01                    20   multiplicative
# 18                     0.05                     5         additive
# 19                     0.05                     5         additive
# 20                     0.05                     5         additive
# 21                     0.05                     5   multiplicative
# 22                     0.05                     5   multiplicative
# 23                     0.05                     5   multiplicative
# 24                     0.05                    10         additive
# 25                     0.05                    10         additive
# 26                     0.05                    10         additive
# 27                     0.05                    10   multiplicative
# 28                     0.05                    10   multiplicative
# 29                     0.05                    10   multiplicative
# 30                     0.05                    20         additive
# 31                     0.05                    20         additive
# 32                     0.05                    20         additive
# 33                     0.05                    20   multiplicative
# 34                     0.05                    20   multiplicative
# 35                     0.05                    20   multiplicative
# 36                     0.10                     5         additive
# 37                     0.10                     5         additive
# 38                     0.10                     5         additive
# 39                     0.10                     5   multiplicative
# 40                     0.10                     5   multiplicative
# 41                     0.10                     5   multiplicative
# 42                     0.10                    10         additive
# 43                     0.10                    10         additive
# 44                     0.10                    10         additive
# 45                     0.10                    10   multiplicative
# 46                     0.10                    10   multiplicative
# 47                     0.10                    10   multiplicative
# 48                     0.10                    20         additive
# 49                     0.10                    20         additive
# 50                     0.10                    20         additive
# 51                     0.10                    20   multiplicative
# 52                     0.10                    20   multiplicative
# 53                     0.10                    20   multiplicative
#
#     seasonality_prior_scale         rmse
# 0                         5  9044.145005
# 1                        10  9058.133399
# 2                        20  9100.757285
# 3                         5  8919.130220
# 4                        10  8961.981225
# 5                        20  8966.752242
# 6                         5  9118.134744
# 7                        10  9061.095591
# 8                        20  9060.348834
# 9                         5  8976.188416
# 10                       10  8943.826525
# 11                       20  8992.029550
# 12                        5  9085.782050
# 13                       10  9042.157781
# 14                       20  9056.451969
# 15                        5  8996.046220
# 16                       10  8933.210414
# 17                       20  8966.261222
# 18                        5  8610.358439
# 19                       10  8613.800692
# 20                       20  8620.938242
# 21                        5  8490.531837
# 22                       10  8490.247521
# 23                       20  8496.640839
# 24                        5  8611.310354
# 25                       10  8631.132509
# 26                       20  8610.468343
# 27                        5  8488.233595
# 28                       10  8496.252785
# 29                       20  8487.322330
# 30                        5  8612.626098
# 31                       10  8624.875230
# 32                       20  8632.525664
# 33                        5  8512.614079
# 34                       10  8499.145766
# 35                       20  8497.003156
# 36                        5  8456.513565
# 37                       10  8455.556338
# 38                       20  8460.055926
# 39                        5  8304.019205
# 40                       10  8309.224174
# 41                       20  8300.072531
# 42                        5  8462.845940
# 43                       10  8454.952765
# 44                       20  8465.740702
# 45                        5  8300.113377
# 46                       10  8294.720345
# 47                       20  8298.669253
# 48                        5  8458.762924
# 49                       10  8454.427167
# 50                       20  8451.977184
# 51                        5  8306.438269
# 52                       10  8307.840466
# 53                       20  8306.903404
