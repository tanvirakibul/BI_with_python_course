# %% [markdown]
# #Directory, Libraries and Data

# %%
# %cd /content/drive/MyDrive/Business Analyst course/Statistics and Descriptive Analytics/Logistic Regression
# Out:
# /content/drive/MyDrive/Business Analyst course/Statistics and Descriptive Analytics/Logistic Regression

# %%
#Libraries 
import pandas as pd
import statsmodels.api as sm 
import seaborn as sns
import numpy as np

# %%
#Load the data
df = pd.read_csv("spam.csv")
df.head()
# Out:
#    crl.tot  dollar   bang  money  n000  make yesno
# 0      278   0.000  0.778   0.00  0.00  0.00     y
# 1     1028   0.180  0.372   0.43  0.43  0.21     y
# 2     2259   0.184  0.276   0.06  1.16  0.06     y
# 3      191   0.000  0.137   0.00  0.00  0.00     y
# 4      191   0.000  0.135   0.00  0.00  0.00     y

# %% [markdown]
# #Data analysis

# %%
#summary statistics
df.describe()
# Out:
#             crl.tot       dollar         bang        money         n000  \
# count   4601.000000  4601.000000  4601.000000  4601.000000  4601.000000
# mean     283.289285     0.075811     0.269071     0.094269     0.101645
# std      606.347851     0.245882     0.815672     0.442636     0.350286
# min        1.000000     0.000000     0.000000     0.000000     0.000000
# 25%       35.000000     0.000000     0.000000     0.000000     0.000000
# 50%       95.000000     0.000000     0.000000     0.000000     0.000000
# 75%      266.000000     0.052000     0.315000     0.000000     0.000000
# max    15841.000000     6.003000    32.478000    12.500000     5.450000
#
#               make
# count  4601.000000
# mean      0.104553
# std       0.305358
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       4.540000

# %%
#histograms
df.hist(figsize= (15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa835146910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa82a76d290>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa82a724890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa82a6dae90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa82a69e4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa82a652ad0>]],
#       dtype=object)

# %%
#removing outliers
print(len(df))
df = df[df["crl.tot"] < 1500]
df = df[df["bang"] < 5]
df = df[df["money"] < 6]
print(len(df))
# Out:
# 4601
# 4432

# %%
#Correlation matrix
sns.heatmap(df.corr(),
            annot = True,
            fmt = '.1g',
            center = 0,
            cmap = 'coolwarm',
            linewidths = 1,
            linecolor = 'black')

# %% [markdown]
# #Logistic Regression preparation

# %%
#Prepare dependent variable
df["yesno"] = np.where(df["yesno"] == "y", 1, 0 )
df.head(1)
# Out:
#    crl.tot  dollar   bang  money  n000  make  yesno
# 0      278     0.0  0.778    0.0   0.0   0.0      1

# %%
#prepare the X and y
y = df.yesno
X = df.iloc[:,:-1]
X = sm.add_constant(X)
X.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
#    const  crl.tot  dollar   bang  money  n000  make
# 0    1.0      278    0.00  0.778   0.00  0.00  0.00
# 1    1.0     1028    0.18  0.372   0.43  0.43  0.21

# %%
#Training and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size = 0.2,
                                                    random_state = 1502)

# %% [markdown]
# #Logistic Regression

# %%
#Logistic Regression
model = sm.Logit(y_train, X_train).fit()
print(model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.386779
#          Iterations 8
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  yesno   No. Observations:                 3545
# Model:                          Logit   Df Residuals:                     3538
# Method:                           MLE   Df Model:                            6
# Date:                Wed, 23 Nov 2022   Pseudo R-squ.:                  0.4210
# Time:                        18:39:15   Log-Likelihood:                -1371.1
# converged:                       True   LL-Null:                       -2368.2
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.1801      0.074    -29.532      0.000      -2.325      -2.035
# crl.tot        0.0017      0.000      8.985      0.000       0.001       0.002
# dollar         6.5798      0.682      9.652      0.000       5.244       7.916
# bang           3.4796      0.191     18.238      0.000       3.106       3.854
# money          3.7237      0.398      9.354      0.000       2.943       4.504
# n000           3.3324      0.452      7.380      0.000       2.447       4.217
# make           0.0216      0.186      0.117      0.907      -0.342       0.385
# ==============================================================================

# %%
#Create the function
def logistic_reader(coefficient):
  probability = round((np.exp(coefficient) - 1) * 100, 2)
  if probability > 0:
    print("The likelihood increases by", probability, "%")
  elif probability == 0:
    print("No impact")
  else:
    print("The likelihood decreases by", probability, "%")

# %%
#Apply the function
logistic_reader(-0.5)
# Out:
# The likelihood decreases by -39.35 %

# %% [markdown]
# #Assess the model

# %%
#predictions
predictions = model.predict(X_test)
predictions = np.where(predictions > 0.5, 1, 0)
predictions[:5]
# Out:
# array([1, 0, 0, 0, 0])

# %%
#Check is dataset is balanced
y_test.mean()
# Out:
# 0.35400225479143177

# %%
#Confusion matrix
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, predictions))
tn, fp, fn, tp = confusion_matrix(y_test, predictions).ravel()
# Out:
# [[524  49]
#  [102 212]]

# %%
#Accuracy
accuracy = (tp + tn) / (tp + tn + fp + fn)
print("Accuracy:", round(accuracy * 100, 1), "%")

#F1_score
f1 = 2 * tp / (2 * tp + fn + fp)
print("F1_score:", round(f1 * 100, 1), "%")

#Specificity
specificity = tn / (tn + fp)
print("Specificity:", round(specificity * 100, 1), "%")

#Sensitivity
sensitivity = tp / (tp + fn)
print("Sensitivity:", round(sensitivity * 100, 1), "%")
# Out:
# Accuracy: 83.0 %
# F1_score: 73.7 %
# Specificity: 91.4 %
# Sensitivity: 67.5 %

# %%
#Classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87       573
#            1       0.81      0.68      0.74       314
#
#     accuracy                           0.83       887
#    macro avg       0.82      0.79      0.81       887
# weighted avg       0.83      0.83      0.83       887
